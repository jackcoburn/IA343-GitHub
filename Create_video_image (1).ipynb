# %% [markdown]
# # Intro to Vison and Video Models

# %% [markdown]
# This notebook uses vision-language models to classify images and diffusion models to recreate and edit them.
#
# If you are using AWS SageMaker, ensure you are using the [Conda PyTorch kernel](https://docs.aws.amazon.com/dlami/latest/devguide/tutorial-pytorch.html) that is specifically optimized for PyTorch-based deep learning tasks.
#
#
# ## Vision-Language Model
# A [Vision-Language Model (VLM)](https://huggingface.co/blog/vlms) is an AI model that integrates visual and textual information, enabling it to understand and generate insights from both images and text. It combines computer vision (to recognize objects and scenes) with natural language processing, allowing tasks like generating image captions, answering questions about images, and creating visuals from text prompts.
#
# ## Diffusion Model
# A [diffusion model](https://huggingface.co/blog/Esmail-AGumaan/diffusion-models) is a generative AI model that creates images by reversing a process of adding noise. It learns to transform random noise into detailed images by progressively removing noise over many steps. Starting with pure noise, the model gradually refines each step until it forms a complete, high-quality image. This approach is highly effective for text-to-image generation and image editing.

# %% [markdown]
# ## Set up API Key

# %% [markdown]
# You also need to purchase and your [openai](https://openai.com/) api key in AWS Secrets Manager:
# - key name: `api_key`
# - key value: <`your openai api key`>
# - secret name: `openai`

# %% [markdown]
# ## Install Python Libraries
#
# - pymongo: manage the MongoDB database
# - openai: use the VLM model and diffusion model

# %%
pip install openai -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Secrets Manager Function

# %%
import boto3
from botocore.exceptions import ClientError
import json

def get_secret(secret_name):
    region_name = "us-east-1"

    # Create a Secrets Manager client
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name
    )

    try:
        get_secret_value_response = client.get_secret_value(
            SecretId=secret_name
        )
    except ClientError as e:
        raise e

    secret = get_secret_value_response['SecretString']
    
    return json.loads(secret)

# %% [markdown]
# ## Import Python Libraries and Credentials

# %%
import json
import re
import os
from openai import OpenAI
from pprint import pprint


openai_api_key  = get_secret('openai')['api_key']
client = OpenAI(api_key=openai_api_key)

# %% [markdown]
# ## Utility Functions
#
# - `get_image_from_url`: Retrieve the image object from a URL.
# - `display_image`: Display an image in Python.
# - `image_to_bytes`: Convert an image to bytes.

# %%
from PIL import Image
from io import BytesIO
import requests

def get_image_from_url(image_url):
    response = requests.get(image_url)
    # print(response)
    if response.status_code == 200 :
        image = Image.open(BytesIO(response.content))
        return image
    else:
        print('image not accessible')
        return None

# %%
import matplotlib.pyplot as plt

def display_image(image):
    if image:
        plt.imshow(image)
        plt.axis('off')
        plt.show()

# %%
from io import BytesIO

def image_to_bytes(image_obj):
    buffer = BytesIO()
    image_obj.save(buffer, format="PNG")
    buffer.seek(0)  # move to beginning so OpenAI can read it
    return buffer

# %% [markdown]
# # Image URL
# Find an online image and past the URL here

# %%
image_url = "https://images.saymedia-content.com/.image/ar_1:1%2Cc_fill%2Ccs_srgb%2Cq_auto:eco%2Cw_1200/MTc2NDUyMzc5OTA1MTcyNjkz/the-serval-cat-an-african-wildcat.png"

# %%
display_image(get_image_from_url(image_url))

# %% [markdown]
# ## Classify Image
#
# Many OpenAI [models](https://platform.openai.com/docs/models) can handle both images and text, allowing you to choose the most suitable model for your needs.
#
# This function summarizes each Twitter image and extracts entities into a JSON document.

# %%
vison_model = 'gpt-4o-mini'
temperature=0

def describe_image(image_url):

    response = client.chat.completions.create(
      model=vison_model,
      messages=[
        {
          "role": "user",
          "content": [
            {"type": "text", "text": """ Analyze the image included in the tweet.
                                        Briefly describe the content of the image and extract entities from it.
                                        Organize the response in a JSON document:
                                        Place the description in the <img_desc> key.
                                        List the entity type and entity value in the <img_entities> key.
                                        Do not wrap the JSON code in JSON markers."""},
            {
              "type": "image_url",
              "image_url": {"url": image_url,},
 
            },
          ],
        }

      ],
    temperature=temperature
     )
    return (response.choices[0].message.content)

# %%
image_result = json.loads(describe_image(image_url))
pprint(image_result)
# Out:
# {'img_desc': 'A serval cat lying on the grass, showcasing its distinctive '
#              'spotted fur and alert expression.',
#  'img_entities': [{'entity_type': 'Animal', 'entity_value': 'Serval'},
#                   {'entity_type': 'Habitat', 'entity_value': 'Grass'}]}

# %% [markdown]
# ## Create Images
# For image generation, you can choose between DALL·E 2 or DALL·E 3. Both models currently support different parameters. Note that only DALL·E 2 can be used to create variations or edit images. Please check the OpenAI [API documentation](https://platform.openai.com/docs/guides/images) for more details.

# %% [markdown]
# ### Create New Image
# Generate a new image based on the provided image description.

# %%
image_model="dall-e-2"  


def create_new_img(prompt):

    resposne = client.images.generate(
    model=image_model,
    prompt=prompt,
    n=1,
    size = "256x256"
    )
    
    
    return(resposne.data[0].url)

# %%
new_image = create_new_img(image_result['img_desc'])

display_image(get_image_from_url(new_image))

# %% [markdown]
# ### Create Variant
# Upload an existing Twitter image and create a variant.

# %%
def create_var_img(image_url):
    img_obj = get_image_from_url(image_url)
    img_byt = image_to_bytes(img_obj)
    response = client.images.create_variation(
        image=img_byt,
        n=1,
        size="256x256",

        )
    return (response.data[0].url)

# %%
var_image = create_var_img(image_url)

display_image(get_image_from_url(var_image))

# %% [markdown]
# ### Edit Image
# Upload Twitter images, mask the desired area, and edit the masked part.

# %%
from io import BytesIO

def create_img_edit(image, img_mask, prompt):
    """Edit an image using DALL·E 2 or GPT-Image-1 with proper PNG encoding."""
    # Convert base image to PNG bytes
    base_buffer = BytesIO()
    image.convert("RGBA").save(base_buffer, format="PNG")
    base_buffer.seek(0)

    # Convert mask to PNG bytes
    mask_buffer = BytesIO()
    img_mask.convert("RGBA").save(mask_buffer, format="PNG")
    mask_buffer.seek(0)

    response = client.images.edit(
        model="dall-e-2",  # or "gpt-image-1"
        image=("base.png", base_buffer, "image/png"),
        mask=("mask.png", mask_buffer, "image/png"),
        prompt=prompt,
        n=1,
        size="256x256"
    )

    return response.data[0].url

# %% [markdown]
# ### Create Mask with PyTorch
# The following code is provided by ChatGPT with the prompt `"Segment image and create masks."`
#
# You can also use foundational models to segment images, such as Meta’s [SAM (Segment Anything Model)](https://ai.meta.com/sam2/).

# %%
from torchvision import models, transforms
from PIL import Image, ImageEnhance
import torch
import numpy as np
import matplotlib.pyplot as plt
from io import BytesIO

# Load the image
image = get_image_from_url(image_url)  # Replace with your image loading method

# ensure RGB
if image.mode != 'RGB':
    image = image.convert('RGB')

# Define transformations (no resizing since images are 150x150)
transform = transforms.Compose([
    transforms.ToTensor(),
])
input_image = transform(image).unsqueeze(0)  # Add batch dimension

# Load the pre-trained DeepLabV3 model
model = models.segmentation.deeplabv3_resnet101(pretrained=True)
model.eval()

# Perform segmentation
with torch.no_grad():
    output = model(input_image)['out'][0]

# Convert output to predicted classes
output_predictions = output.argmax(0).byte().numpy()


# Create a transparent RGBA mask with fully transparent non-segmented areas
height, width = output_predictions.shape
mask = np.zeros((height, width, 4), dtype=np.uint8)  # 4 channels for RGBA

# Define a color for segmented areas (e.g., semi-transparent red)
color = [255, 0, 0, 180]  # Red with 70% opacity
mask[output_predictions > 0] = color  # Apply color to segmented areas only

# Convert mask to a PIL Image
mask_image = Image.fromarray(mask, mode="RGBA")

# Overlay mask onto the contrast-enhanced original image
image_with_mask = Image.alpha_composite(image.convert("RGBA"), mask_image)

# Display the original image and transparent mask overlay
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(image)
axs[0].axis('off')
axs[0].set_title(" Image")

axs[1].imshow(image_with_mask)
axs[1].axis('off')
axs[1].set_title("Image Transparent Mask")

plt.show()

# %%
img_edit = create_img_edit(image,mask_image,'inside of a living room')

display_image(
    get_image_from_url(img_edit))

# %% [markdown]
# # Create videos

# %% [markdown]
# Create video with a pommpt

# %%
def create_video(prompt):

    video = client.videos.create(

        prompt=prompt,
 
        )
    return(video)

# %%
video = create_video('a person is eating a book')

# %%
print(video.id)
# Out:
# video_69150cf1eb088198bdc91f84ab1145f80fb6f18983367f81

# %%
page = client.videos.list()
page = page.data
pprint(page)
# Out:
# [Video(id='video_69150cf1eb088198bdc91f84ab1145f80fb6f18983367f81', completed_at=None, created_at=1762987249, error=None, expires_at=None, model='sora-2', object='video', progress=0, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='queued'),
#  Video(id='video_69150c30088081988e9058eee9d965fe0de2c8cb97dee43c', completed_at=1762987138, created_at=1762987056, error=None, expires_at=1762990738, model='sora-2', object='video', progress=100, prompt='a baby who has jsut been born grew wings and fly away from the hospital room', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150ae0c5148190a9066fa9c21aea620a2b362e7ab8148b', completed_at=1762986790, created_at=1762986720, error=None, expires_at=1762990390, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150ac2ca088198841e6f0b19e7dc580669cde145e78768', completed_at=1762986767, created_at=1762986690, error=None, expires_at=1762990367, model='sora-2', object='video', progress=100, prompt='a doorbell camera video of a jamaican hippopotamus dressed as a detective asking for somebody to come outside and answer his questions about a crocodile on the loose', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150a6fee048198ac0cf841df82a6750b9f5c880c85bb29', completed_at=1762986679, created_at=1762986607, error=None, expires_at=1762990279, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150a6b69ac8198b301ddb6e8244da3064f9843fb02e319', completed_at=1762986673, created_at=1762986603, error=None, expires_at=1762990273, model='sora-2', object='video', progress=100, prompt='a doorbell camera video of a jamaican hippopotamus dressed as a detective asking for somebody to come outside and answer his questions about a crocodile on the loose', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150a69437c8193bc6990dd8b7cf4ad070a2256a4411f70', completed_at=1762986681, created_at=1762986601, error=None, expires_at=1762990281, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150a641d388198b94b1b5f822ad13b02c499183f744d0e', completed_at=1762986672, created_at=1762986596, error=None, expires_at=1762990272, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150a4b499081909367818cb2dd47f2051ea07ffbf2829d', completed_at=1762986639, created_at=1762986571, error=None, expires_at=1762990239, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150a3f91a08191bad2c89faf3de4aa082f540555b559e1', completed_at=1762986635, created_at=1762986559, error=None, expires_at=1762990235, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150a0fa8f481919a4829fede1c508900444743aa8b7a7a', completed_at=1762986590, created_at=1762986511, error=None, expires_at=1762990190, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150a0e47b88193b15c2700b4a413860fd4297e32e5a48f', completed_at=1762986581, created_at=1762986510, error=None, expires_at=1762990181, model='sora-2', object='video', progress=100, prompt='a mountain being split in half', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150a063d208190b872dd3da226c7ed03e5e61d076bd676', completed_at=1762986571, created_at=1762986502, error=None, expires_at=1762990171, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150a03f6408190b58f453c57586a5f098e71c556bc1cad', completed_at=1762986575, created_at=1762986500, error=None, expires_at=1762990175, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_69150a0391448198bd9425d0f1ce1f4c0eee4946404f5bbd', completed_at=1762986595, created_at=1762986499, error=None, expires_at=1762990195, model='sora-2', object='video', progress=100, prompt='a person is petting a dog', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_691509ef42c88190b157cb5fdbe5467a08becae29726c68b', completed_at=1762986560, created_at=1762986479, error=None, expires_at=1762990160, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_6915098612b881919ce33b94b52da928071fb8e439d75483', completed_at=1762986445, created_at=1762986374, error=None, expires_at=1762990045, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_691508e2d2e481938857c11394a0e2ec0f7de40a0a89233c', completed_at=1762986283, created_at=1762986210, error=None, expires_at=1762989883, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_691508b87e7481909cc89a1f7c9adc300ca6054212be38b7', completed_at=1762986253, created_at=1762986168, error=None, expires_at=1762989853, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed'),
#  Video(id='video_691506cab2208191b09cbbbf71ec623903a2149ece2cddce', completed_at=1762985747, created_at=1762985674, error=None, expires_at=1762989347, model='sora-2', object='video', progress=100, prompt='a person is eating a book', remixed_from_video_id=None, seconds='4', size='720x1280', status='completed')]

# %% [markdown]
# Waite untile your video id appears in the following list

# %%
response = client.videos.download_content(
    video_id=video.id,
)
content = response.read()

# Save to file
output_path = f"generated_video_{video.id}.mp4"
with open(output_path, "wb") as f:
    f.write(content)

print(f"Video saved to: {output_path}")
# Out:
# Video saved to: generated_video_video_6914c62103988198ad6e29b1453912800483fd0315257b03.mp4

# %% [markdown]
# ## Respoisbile AI
# Many image model providers update their security measures to foster responsible AI usage. For example, AWS adds watermarks to images generated by Amazon Titan. OpenAI has updated its safety features, including monitoring for abuse, access control, and the identification of images created by DALL·E 3.

# %% [markdown]
# ## References
#
# - Amazon Web Services, Inc. *“Watermark Detection for Amazon Titan Image Generator Now Available in Amazon Bedrock.”* Accessed November 7, 2024. [https://aws.amazon.com/about-aws/whats-new/2024/04/watermark-detection-amazon-titan-image-generator-bedrock/](https://aws.amazon.com/about-aws/whats-new/2024/04/watermark-detection-amazon-titan-image-generator-bedrock/).
#
# - Esmail Atta Gumaan. *“Diffusion Models.”* Hugging Face (blog). Accessed November 7, 2024. https://huggingface.co/blog/Esmail-AGumaan/diffusion-models.
#
# - Merve Noyan and Edward Beeching. *“Vision Language Models Explained.”* Hugging Face (blog). Accessed November 6, 2024. [https://huggingface.co/blog/vlms](https://huggingface.co/blog/vlms).
#
# - *“OpenAI Safety Practices.”* Accessed November 7, 2024. [https://openai.com/index/openai-safety-update/](https://openai.com/index/openai-safety-update/).
